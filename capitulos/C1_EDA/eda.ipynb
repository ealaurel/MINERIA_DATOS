# %% [markdown]
# # 1. LIBRERIAS Y FUNCIONES

# %%
import pandas as pd

# %% [markdown]
# # 2. PARÁMETROS

# %% [markdown]
# # 3. DATOS

# %%
df_bfv = pd.read_csv("data/black_friday_ventas.csv")
df_bfv.head()

# %% [markdown]
# # 4. PROCESO

# %% [markdown]
# # 5. SALIDA
