# %% [markdown]
# ## 🔍 EDA en el contexto de CRISP-DM
#
# ### 1. **Objetivo del EDA**
# - Comprender la naturaleza de los datos antes de aplicar modelos.
# - Detectar patrones, anomalías y relaciones.
# - Evaluar la calidad y completitud de los datos.
# - Generar hipótesis iniciales sobre el problema de negocio.
#
# ---
#
# ### 2. **Pasos clave del EDA**
# #### a) **Revisión inicial de los datos**
# - Dimensiones del dataset (número de filas y columnas).
# - Tipos de variables: numéricas, categóricas, fechas, texto.
# - Ejemplo: dataset de ventas → columnas como “precio”, “categoría”, “fecha”.
#
# #### b) **Calidad de los datos**
# - Valores faltantes (missing values).
# - Duplicados.
# - Errores de formato (ej. fechas mal registradas).
# - Ejemplo: registros de clientes con edad = 0 o >120.
#
# #### c) **Distribución de variables**
# - Histogramas y frecuencias.
# - Medidas de tendencia central (media, mediana, moda).
# - Medidas de dispersión (varianza, desviación estándar).
# - Ejemplo: distribución de ingresos de clientes para detectar sesgos.
#
# #### d) **Relaciones entre variables**
# - Correlaciones (Pearson, Spearman).
# - Tablas cruzadas para variables categóricas.
# - Ejemplo: relación entre nivel educativo y salario.
#
# #### e) **Detección de outliers**
# - Boxplots para identificar valores extremos.
# - Ejemplo: ventas de un día que superan 10 veces el promedio.
#
# #### f) **Visualización exploratoria**
# - Gráficos de dispersión, barras, heatmaps.
# - Ejemplo: mapa de calor de correlaciones para ver qué variables se relacionan más con el objetivo.
#
#
# ### 5. **Actividad práctica en clase**
# - Cada grupo usa el dataset planteado para su poryecto de la materia
# - Guía de preguntas:
#   1. ¿Qué variables hay y cómo se clasifican?
#   2. ¿Qué problemas de calidad detectan?
#   3. ¿Qué patrones iniciales observan?
#   4. ¿Qué hipótesis pueden plantear sobre el negocio?
# - Presentación rápida de hallazgos (2 min por grupo).

# %% [markdown]
# # 1. LIBRERIAS Y FUNCIONES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. PARÁMETROS

# %% [markdown]
# # 3. DATOS

# %%
# df: data_frame
df_bfv = pd.read_csv("data/black_friday_ventas.csv")
df_bfv.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %% [markdown]
# # 4. PROCESO

# %% [markdown]
# ## 4.1 Revisión inicial de los datos

# %% [markdown]
# - Dimensiones del dataset

# %%
# número de filas y columnas
df_bfv.shape
# Out:
# (550068, 12)

# %%
# tipos de variables, revisar el tipo de variable
df_bfv.dtypes
# Out:
# User_ID                           str
# Product_ID                        str
# Gender                            str
# Age                               str
# Occupation                        str
# City_Category                     str
# Stay_In_Current_City_Years        str
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
df_bfv['User_ID'] = df_bfv['User_ID'].astype(str)
df_bfv['Occupation'] = df_bfv['Occupation'].astype(str)

# %% [markdown]
# ## 4.2. Calidad de los datos

# %%
# valores faltantes
df_bfv.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
# imputaremos la vairbale product?catregory_2 porla moda
moda = df_bfv['Product_Category_2'].mode()[0]
df_bfv['Product_Category_2'] = df_bfv['Product_Category_2'].fillna(moda)

# %%
df_bfv.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2                 0
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
# revisaremos las filas duplicas y las eliminamos
print('filas originales del data frame',df_bfv.shape)
print('filas después de eliminar duplicados',df_bfv.drop_duplicates().shape)
# Out:
# filas originales del data frame (550068, 12)
# filas después de eliminar duplicados (550068, 12)

# %% [markdown]
# ## 4.3. Distribución de variables

# %%
# HISTOGRAMA

# Histograma con Seaborn
sns.histplot(df_bfv["Purchase"], bins=10, kde=True, color="skyblue")
plt.title("Distribución de Precios o Montos")
plt.xlabel("Precio")
plt.ylabel("Frecuencia")
plt.show()

# %%
# Boxplot(diagrama de cajas bigotes) con Seaborn
sns.boxplot(x=df_bfv["Purchase"], color="lightgreen")
plt.title("Boxplot de Precios")
plt.xlabel("Precio")
plt.show()

# %% [markdown]
# ## 4.4 Relacion entre variables

# %%
df_bfv.dtypes
# Out:
# User_ID                           str
# Product_ID                        str
# Gender                            str
# Age                               str
# Occupation                        str
# City_Category                     str
# Stay_In_Current_City_Years        str
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
df_bfv['Stay_In_Current_City_Years'].value_counts()
# Out:
# Stay_In_Current_City_Years
# 1     193821
# 2     101838
# 3      95285
# 4+     84726
# 0      74398
# Name: count, dtype: int64

# %%
# solo tomamos valores numericos del 0 al 9 del campo Stay_In_Current_City_Years y lo guardamos en otro campo 
df_bfv['nro_anios_en_ciudad'] = df_bfv['Stay_In_Current_City_Years'].str[0]
df_bfv['nro_anios_en_ciudad'] = df_bfv['nro_anios_en_ciudad'].astype(int)

# %%
df_bfv.dtypes
# Out:
# User_ID                           str
# Product_ID                        str
# Gender                            str
# Age                               str
# Occupation                        str
# City_Category                     str
# Stay_In_Current_City_Years        str
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# nro_anios_en_ciudad             int64
# dtype: object

# %%
# CORRELACIONES ENTRE VARIABLES
# Dataset de ejemplo con más variables
# Heatmap de correlaciones
corr = df_bfv[['Purchase','nro_anios_en_ciudad']].corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Mapa de calor de correlaciones")
plt.show()

# %%
# hacer un arbol de decisión para predecir los valores faltantes de Product_Category_2 a partir de las variables Purchase y Product_Category_1
from sklearn.tree import DecisionTreeClassifier
# separamos las filas con valores faltantes de Product_Category_2
df_bfv_train = df_bfv[df_bfv['Product_Category_2'].notnull()]
df_bfv_test = df_bfv[df_bfv['Product_Category_2'].isnull()]
# separamos las variables predictoras y la variable objetivo
X_train = df_bfv_train[['Purchase', 'Product_Category_1']]
y_train = df_bfv_train['Product_Category_2']
X_test = df_bfv_test[['Purchase', 'Product_Category_1']]
# entrenamos el modelo
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# predecimos los valores faltantes  
y_pred = model.predict(X_test)
# asignamos los valores predichos a la variable Product_Category_2 en el dataframe original
#df_bfv.loc[df_bfv['Product_Category_2'].isnull(), 'Product_Category_2'] = y_pred

# %%
y_pred
# Out:
# array([ 4., 14., 14., ..., 14., 15., 16.], shape=(173638,))

# %%
df_bfv[df_bfv['Product_Category_2'].isnull()]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 9       1000005  P00274942      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
# revisamos por producto
df_bfv[df_bfv['Product_Category_1']==3].groupby(['Product_Category_1','Product_Category_2'],dropna=False).agg(nro_trx = ('Product_ID', 'count')
                                                                                                                                 ,avg_purchase = ('Purchase', 'mean')
                                                                                                                                 )#.sort_values(ascending=False).head(10)
# Out:
#                                        nro_trx  avg_purchase
# Product_Category_1 Product_Category_2
# 3                  4.0                   16858   9953.985704
#                    5.0                    2264  11002.631625
#                    12.0                    595   9692.831933
#                    13.0                     26  11055.692308
#                    15.0                    231  10821.502165
#                    NaN                     239  11782.485356

# %%
df_bfv[(df_bfv['Product_ID']=='P00255842')\
       #& (df_bfv['Product_Category_2'].notnull())
       ][['Product_ID','Product_Category_1','Product_Category_2','Purchase']]
# Out:
#        Product_ID  Product_Category_1  Product_Category_2  Purchase
# 234     P00255842                  16                 NaN     20961
# 506     P00255842                  16                 NaN     16416
# 1116    P00255842                  16                 NaN     12379
# 1460    P00255842                  16                 NaN     20742
# 1806    P00255842                  16                 NaN     16875
# ...           ...                 ...                 ...       ...
# 544846  P00255842                  16                 NaN     20283
# 544928  P00255842                  16                 NaN     20296
# 545007  P00255842                  16                 NaN     16874
# 545142  P00255842                  16                 NaN      8340
# 545461  P00255842                  16                 NaN     20634
#
# [1383 rows x 4 columns]

# %%
# Boxplot con Seaborn
sns.boxplot(x=df["Purchase"], color="lightgreen")
plt.title("Boxplot de Precios")
plt.xlabel("Precio")
plt.show()

# %% [markdown]
# # 5. SALIDA
