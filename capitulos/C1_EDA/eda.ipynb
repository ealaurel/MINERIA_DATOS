# %% [markdown]
# # 1. LIBRERIAS Y FUNCIONES

# %%
import pandas as pd

# %% [markdown]
# # 2. PARÁMETROS

# %% [markdown]
# # 3. DATOS

# %%
df_bfv = pd.read_csv("data/black_friday_ventas.csv")
df_bfv.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %% [markdown]
# # 4. PROCESO

# %% [markdown]
# ## 4.1 Revisión inicial de los datos

# %% [markdown]
# - Dimensiones del dataset

# %%
# número de filas y columnas
df_bfv.shape
# Out:
# (550068, 12)

# %%
# tipos de variables
df_bfv.dtypes
# Out:
# User_ID                         int64
# Product_ID                        str
# Gender                            str
# Age                               str
# Occupation                      int64
# City_Category                     str
# Stay_In_Current_City_Years        str
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %% [markdown]
# ## 4.2. Calidad de los datos

# %%
# valores faltantes
df_bfv.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
# revisamos por producto
df_bfv[df_bfv['Product_Category_2'].isnull()].groupby(['Product_ID','Product_Category_1','Product_Category_2'],dropna=False).size().sort_values(ascending=False).head(10)
# Out:
# Product_ID  Product_Category_1  Product_Category_2
# P00255842   16                  NaN                   1383
# P00278642   5                   NaN                   1226
# P00031042   8                   NaN                   1200
# P00258742   5                   NaN                    964
# P00110542   8                   NaN                    958
# P00106042   5                   NaN                    905
# P00371644   20                  NaN                    899
# P00372445   20                  NaN                    837
# P00156442   8                   NaN                    835
# P00370853   19                  NaN                    818
# dtype: int64

# %%
df_bfv[(df_bfv['Product_ID']=='P00255842')\
       #& (df_bfv['Product_Category_2'].notnull())
       ][['Product_ID','Product_Category_1','Product_Category_2','Purchase']]
# Out:
#        Product_ID  Product_Category_1  Product_Category_2  Purchase
# 234     P00255842                  16                 NaN     20961
# 506     P00255842                  16                 NaN     16416
# 1116    P00255842                  16                 NaN     12379
# 1460    P00255842                  16                 NaN     20742
# 1806    P00255842                  16                 NaN     16875
# ...           ...                 ...                 ...       ...
# 544846  P00255842                  16                 NaN     20283
# 544928  P00255842                  16                 NaN     20296
# 545007  P00255842                  16                 NaN     16874
# 545142  P00255842                  16                 NaN      8340
# 545461  P00255842                  16                 NaN     20634
#
# [1383 rows x 4 columns]

# %% [markdown]
# # 5. SALIDA
